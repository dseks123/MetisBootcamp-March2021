# %% [markdown]
# # PROJECT MVP
#
# Product Name has been re-imagined from Sip-Aaah! to Xylo.
#
# Focus on commuter numbers has been taken precedence over rolling out an even foot-print across New York.
# Special emphasis on pedestrian traffic, to identify which data identifying the 50 busiest stations in New York has been extracted from MTA (see attached plot)
#
# This is the focus area around which all project deliverables will be centered.
#
# ![top_50_stations.png](attachment:top_50_stations.png)
